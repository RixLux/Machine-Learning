# %%
import matplotlib.pyplot as plt

# Use square brackets [] for lists to preserve order and duplicates
x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

plt.scatter(x, y)
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Scatter Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy import stats

# Data (as lists)
x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

# 1. Perform linear regression
slope, intercept, r, p, std_err = stats.linregress(x, y)

# 2. Function to calculate predicted y values using the linear equation: y = mx + c
def predict_y(x_val):
    return slope * x_val + intercept

# 3. Create a list of predicted y values (the regression line)
regression_line = list(map(predict_y, x))

# 4. Create the scatter plot and regression line
plt.scatter(x, y, label='Data Points')
plt.plot(x, regression_line, color='red', label=f'Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Add labels and a title
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title(f'Linear Regression Analysis (R² = {r**2:.2f})')
plt.legend()
plt.show()

# Print statistical summary
print(f"Slope: {slope:.4f}")
print(f"Intercept: {intercept:.4f}")
print(f"Correlation Coefficient (r): {r:.4f}")
print(f"R-squared: {r**2:.4f}")
# Out:
# Slope: -1.7513
# Intercept: 103.1060
# Correlation Coefficient (r): -0.7586
# R-squared: 0.5755

# %%
import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451026

# %%
import numpy
from sklearn.metrics import r2_score

x = [28,20,21,23,17,25,22,19,27,25,24,17]
y = [21,24,27,22,26,24,23,25,21,22,25,28]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.6757458494787141

# %%
import matplotlib.pyplot as plt
from scipy import stats

# Data (as lists)
x = [28,20,21,23,17,25,22,19,27,25,24,17]
y = [21,24,27,22,26,24,23,25,21,22,25,28]

# 1. Perform linear regression
slope, intercept, r, p, std_err = stats.linregress(x, y)

# 2. Function to calculate predicted y values using the linear equation: y = mx + c
def predict_y(x_val):
    return slope * x_val + intercept

# 3. Create a list of predicted y values (the regression line)
regression_line = list(map(predict_y, x))

# 4. Create the scatter plot and regression line
plt.scatter(x, y, label='Data Points')
plt.plot(x, regression_line, color='red', label=f'Regression Line: y = {slope:.2f}x + {intercept:.2f}')

# Add labels and a title
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title(f'Linear Regression Analysis (R² = {r**2:.2f})')
plt.legend()
plt.show()

# Print statistical summary
print(f"Slope: {slope:.4f}")
print(f"Intercept: {intercept:.4f}")
print(f"Correlation Coefficient (r): {r:.4f}")
print(f"R-squared: {r**2:.4f}")
# Out:
# Slope: -0.5114
# Intercept: 35.4205
# Correlation Coefficient (r): -0.8132
# R-squared: 0.6612
